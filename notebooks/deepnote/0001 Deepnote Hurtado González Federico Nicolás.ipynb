# %% [markdown]
# # TP01 \- Deepnote Hurtado González Federico Nicolás

# %% [markdown]
# Me llamo Federico, tengo 32 años y actualmente trabajo como analista de datos en el Ministerio de Hacienda y Finanzas del GCBA\. Me considero una persona muy entusiasta y en constante aprendizaje\. Tengo muchas ganas de cursar esta materia, ver el desarrollo de la misma y poder adquirir nuevas herramientas y conocimientos\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c52a2e13-6b5a-4ebb-82ac-884144cdbe8c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
